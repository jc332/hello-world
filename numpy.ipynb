# %% [markdown]
# <a href="https://colab.research.google.com/github/jc332/hello-world/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
revenus = [1800, 1500, 2200, 3000, 2172]

def moyenne(liste):

    return sum(liste)/len(liste)
moyenne (revenus)
# Out:
# 2134.4

# %%
import numpy as np

x = [-2, -1, 1, 2]
print("La valeur absolue: ", np.abs(x))
print("Exponentielle: ", np.exp(x))
print("Logarithme: ", np.log(np.abs(x)))
# Out:
# La valeur absolue:  [2 1 1 2]
# Exponentielle:  [0.13533528 0.36787944 2.71828183 7.3890561 ]
# Logarithme:  [0.69314718 0.         0.         0.69314718]
