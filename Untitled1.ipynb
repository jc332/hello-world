# %% [markdown]
# <a href="https://colab.research.google.com/github/jc332/hello-world/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
villeFavoriteUne = "Marseille"
villeFavoriteDeux = "Paris"
favori = "Mes villes favorites sont " + villeFavoriteUne + " et " + villeFavoriteDeux
print(favori)
# Out:
# Mes villes favorites sont Marseille et Paris

# %%
ville = "New York"
nombreVoyage = 20
visite = " J'ai déja été à " +  ville + " " +  str( nombreVoyage ) + " fois "
print(visite)
# Out:
#  J'ai déja été à New York 20 fois
